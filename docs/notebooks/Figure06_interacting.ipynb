# %% [markdown]
# # Fig 6 (Appendix C.2) — Larger g deepens the Rodeo advantage at each interaction J
#
# Regenerates `fig_interacting_collapse.pdf` via the shared builder in `reproduce/figures/build_appendix_figs.py` (exact diagonalization; no Aer).

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../../reproduce/figures"))
import importlib, build_appendix_figs as B
importlib.reload(B)
# shared, validated builder writes the canonical-named PDF into the cwd

# %%
B.OUT_DIRS = ["."]
B.fig11()
print("2x2 over J; four fixed g per panel (shared legend)")
