# %% [markdown]
# # Fig 13 — Two gaps correlated; advantage is in the encoding
#
# Regenerates `Figure13_two_gaps` via the shared builder in `reproduce/figures/build_appendix_figs.py` (exact diagonalization; no Aer).

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../../reproduce/figures"))
import importlib, build_appendix_figs as B
importlib.reload(B)
# shared, validated builder writes the canonical-named PDF into the cwd

# %%
B.OUT_DIRS = ["."]
B.fig13()
print("g ~ 0.59 g_decay; exponential encoding advantage")
