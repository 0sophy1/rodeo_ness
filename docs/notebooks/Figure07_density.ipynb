# %% [markdown]
# # Fig 7 (Appendix C.3) — Spectral density is a subleading, saturating effect
#
# Regenerates `fig_density_saturation.pdf` via the shared builder in `reproduce/figures/build_appendix_figs.py` (exact diagonalization; no Aer).

# %%
import sys, os
sys.path.insert(0, os.path.abspath("../../reproduce/figures"))
import importlib, build_appendix_figs as B
importlib.reload(B)
# shared, validated builder writes the canonical-named PDF into the cwd

# %%
B.OUT_DIRS = ["."]
B.fig12()
print("density effect saturates after a few modes")
